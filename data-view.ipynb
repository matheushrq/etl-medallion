# %%
import pandas as pd
import sqlalchemy

db_url = "postgresql://usuario:senha@host:porta/database"
db_path = db_url # para manter compatibilidade com o código existente

# lendo a query do arquivo
with open('03-gold-enriched/pg_session.sql', 'r', encoding='utf-8') as file:
    query = file.read()

# conectando ao banco de dados e executando a query
# engine = sqlalchemy.create_engine(db_url)
with sqlalchemy.create_engine(db_path).connect() as connection:
    df = pd.read_sql_query(query, connection)

df.head()
# Out:
#     id                  nome                       email       telefone  \
# 0  1.0       Ana Paula Silva         ana.silva@email.com  11987654321.0
# 1  2.0  Carlos Eduardo Souza      carlos.souza@email.com  21999887766.0
# 2  3.0      Mariana Oliveira  mariana.oliveira@email.com  31988776655.0
# 3  4.0       João Pedro Lima         joao.lima@email.com  41977665544.0
# 4  5.0        Fernanda Costa    fernanda.costa@email.com  51966554433.0
#
#          cep data_nascimento     genero      cep.1  \
# 0  01001-000      1990-05-12   Feminino  01001-000
# 1  20040-010      1985-11-23  Masculino  20040-010
# 2  30130-010      1992-07-08   Feminino  30130-010
# 3  80010-000      1988-03-15  Masculino  80010-000
# 4  90010-320      1995-09-30   Feminino  90010-320
#
#                      logradouro           complemento  ...   ddd   siafi  \
# 0                   Praça da Sé            lado ímpar  ...  11.0  7107.0
# 1     Avenida Presidente Vargas  até 309 - lado ímpar  ...  21.0  6001.0
# ...
